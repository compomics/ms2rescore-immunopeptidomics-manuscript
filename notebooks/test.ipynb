# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from math import sqrt
from math import acos
from scipy.stats import pearsonr
import matplotlib.pyplot as plt
import seaborn as sns
from immuno_ms2rescore_tools.file_utilities import PrositLib
import pickle

# %%
def ms2pip_pearson(true, pred):
    """
    Return pearson of tic-normalized, log-transformed intensities, 
    the MS2PIP way.
    """
    #tic_norm = lambda x: x / np.sum(x)
    # log_transform = lambda x: np.log2(x + 0.001)
    corr = pearsonr(
        true, 
        pred
    )[0]
    return (corr)

# %%
def spectral_angle(true, pred, epsilon=1e-7):
    """
    Return square root normalized spectral angle.
    See https://doi.org/10.1074/mcp.O113.036475
    """
    
    de_log = lambda x: (2**x)-0.001
    l2_normalize = lambda x: x / sqrt(max(sum(x**2), epsilon))
    
    pred_norm = l2_normalize(de_log(pred))
    true_norm = l2_normalize(de_log(true))
    
    spectral_angle = 1 - (2 * acos(np.dot(pred_norm, true_norm)) / np.pi)

    return (spectral_angle)

# %%
class Scorer:
    def __init__(self,psmids):
        self.psmids = psmids
        
    def psm_score(self,targets, predictions):
        tmp = pd.DataFrame(columns=["psmids", "targets", "predictions"])
        tmp["psmids"] = np.array(self.psmids)
        tmp["targets"] = np.array(targets)
        tmp["predictions"] = np.array(predictions)
        tmp2 = tmp.groupby("psmids").agg({'predictions': list, 'targets': list}).reset_index()
        spectral_corr = []
        pearson_corr = []
        for spectra in range(0, len(tmp2["psmids"])):
            spectral_corr.append(spectral_angle(np.array(tmp2.targets.loc[spectra]), np.array(tmp2.predictions.loc[spectra])))
            pearson_corr.append(ms2pip_pearson(np.array(tmp2.targets.loc[spectra]), np.array(tmp2.predictions.loc[spectra])))
        return (pearson_corr, spectral_corr, tmp2["psmids"])

# %%
myprositlib_pxd005231 = PrositLib("data/evaluation_data/PXD005231/myPrositLib_PXD005231.csv")
myprositlib_pxd005231.remove_carbamidomethyl()
myprositlib_pxd005231.merge_spec_ids("data/evaluation_data/PXD005231/PXD005231_prosit.csv")
prosit_immunopeptide = myprositlib_pxd005231.create_pred_and_emp_csv("data/evaluation_data/PXD005231/spec_lib_PXD005231_HCD_pred_and_emp.csv")

# %%
prosit_test = pd.DataFrame(columns = ["pearson correlation", "spectral angle"])
prosit_scorer = Scorer(prosit_immunopeptide["spec_id"])
prosit_test["pearson correlation"], prosit_test["spectral angle"],prosit_test["psmid"]  = prosit_scorer.psm_score(prosit_immunopeptide["target"],prosit_immunopeptide["prediction"])
prosit_test["evaluation data set"] = "shotgun proteomics"
# Out:
# /home/arthur/miniconda3/envs/ms2pip-dev/lib/python3.8/site-packages/scipy/stats/stats.py:3508: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())

# %%
#prosit_immunopeptide["spec_id"] == "mzspec:PXD005231:20160902_QEh1_LC2_CHC_SA_HLApI_TIL3_2:scan:49077"

# %%
myprositlib_pxd020011 = PrositLib("data/evaluation_data/PXD020011/myPrositLib_PXD020011.csv")
myprositlib_pxd020011.remove_carbamidomethyl()
myprositlib_pxd020011.merge_spec_ids("data/evaluation_data/PXD020011/PXD020011_prosit.csv")
prosit_hlaII = myprositlib_pxd020011.create_pred_and_emp_csv("data/evaluation_data/PXD020011/spec_lib_pxd020011_HCD_pred_and_emp.csv")
prosit_hlaII_Y = prosit_hlaII[prosit_hlaII["ion"] == "Y"]
prosit_hlaII_B = prosit_hlaII[prosit_hlaII["ion"] == "B"]

# %%
myprositlib_pxd020011.prositlib[myprositlib_pxd020011.prositlib["spec_id"] == "mzspec:True:20171216_QEh1_LC1_HLAIIp_SA_FaMa_Leuka2_MDC_2_R2:scan:5469"]
# Out:
#         RelativeIntensity  FragmentMz    ModifiedPeptide     LabeledPeptide  \
# 142506           0.700359  156.076752  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142507           0.013189  285.119354  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142508           0.000189   89.707779  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142509           0.000716  398.203400  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142510           0.003058  141.741486  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142511           0.047132  554.304504  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142512           0.015999  277.655884  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142513           0.000175  170.752151  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142514           0.112026  683.347107  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142515           0.056192  342.177185  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142516           0.008283  333.675140  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142517           0.062490  811.442078  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142518           0.066152  406.224670  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142519           0.005125  390.217194  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142520           0.028233  470.253967  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142521           0.028842  454.738495  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142522           0.010942  526.796021  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142523           0.057319  518.785950  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142524           0.001172  346.193054  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142525           0.044941  570.312012  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142526           0.048766  562.302002  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142527           0.004255  375.203735  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142528           0.023418  634.359497  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142529           0.114120  618.843994  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142530           0.009252  412.898438  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142531           0.007090  698.880798  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142532           0.146740  682.873291  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142533           0.049696  455.584625  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142534           0.000582  503.950958  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142535           0.029768  746.920776  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142536           0.157802  498.282959  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142537           0.008533  555.984680  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142538           0.089175  541.297119  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142539           0.015084  584.995361  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142540           0.047881  593.330872  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142541           0.004715  637.029053  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142542           0.091869  631.025513  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
# 142543           1.000000  674.039734  EHRSRLEKSLQKERLEH  EHRSRLEKSLQKERLEH
#
#           StrippedPeptide  PrecursorCharge  PrecursorMz        iRT  \
# 142506  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142507  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142508  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142509  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142510  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142511  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142512  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142513  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142514  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142515  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142516  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142517  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142518  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142519  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142520  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142521  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142522  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142523  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142524  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142525  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142526  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142527  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142528  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142529  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142530  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142531  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142532  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142533  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142534  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142535  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142536  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142537  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142538  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142539  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142540  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142541  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142542  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
# 142543  EHRSRLEKSLQKERLEH                4   544.541711 -13.758358
#
#         proteotypicity  FragmentNumber FragmentType  FragmentCharge  \
# 142506        0.298364               1            y               1
# 142507        0.298364               2            y               1
# 142508        0.298364               2            b               3
# 142509        0.298364               3            y               1
# 142510        0.298364               3            b               3
# 142511        0.298364               4            y               1
# 142512        0.298364               4            y               2
# 142513        0.298364               4            b               3
# 142514        0.298364               5            y               1
# 142515        0.298364               5            y               2
# 142516        0.298364               5            b               2
# 142517        0.298364               6            y               1
# 142518        0.298364               6            y               2
# 142519        0.298364               6            b               2
# 142520        0.298364               7            y               2
# 142521        0.298364               7            b               2
# 142522        0.298364               8            y               2
# 236480   375.203735       4          9   B  1123.59640 -9.965784
# 236481   618.843994       4         10   B  1236.68050 -9.965784
# 236482   412.898438       4         10   B  1236.68050 -9.965784
# 236483   682.873291       4         11   B  1364.73910 -9.965784
# 236484   455.584625       4         11   B  1364.73910 -9.965784
# 236485   746.920776       4         12   B  1492.83410 -9.965784
# 236486   498.282959       4         12   B  1492.83410 -9.965784
# 236487   541.297119       4         13   B  1621.87670 -9.965784
# 236488   593.330872       4         14   B  1777.97780 -9.965784
# 236489   631.025513       4         15   B  1891.06190 -9.965784
# 236490   674.039734       4         16   B  2020.10450 -9.965784
# 236491   156.076752       4          1   Y   156.07672 -5.054863
# 236492   285.119354       4          2   Y   285.11930 -9.361670
# 236493   398.203400       4          3   Y   398.20334 -9.965784
# 236494   554.304504       4          4   Y   554.30444 -7.996569
# 236495   277.655884       4          4   Y   554.30444 -7.996569
# 236496   683.347107       4          5   Y   683.34705 -6.523129
# 236497   342.177185       4          5   Y   683.34705 -6.523129
# 236498   811.442078       4          6   Y   811.44200 -6.798137
# 236499   406.224670       4          6   Y   811.44200 -6.798137
# 236500   470.253967       4          7   Y   939.50060 -8.518956
# 236501   526.796021       4          8   Y  1052.58470 -9.965784
# 236502   570.312012       4          9   Y  1139.61670 -9.965784
# 236503   634.359497       4         10   Y  1267.71170 -9.965784
# 236504   698.880798       4         11   Y  1396.75430 -9.965784
# 236505   503.950958       4         12   Y  1509.83840 -9.965784
# 236506   555.984680       4         13   Y  1665.93950 -9.965784
# 236507   584.995361       4         14   Y  1752.97140 -9.965784
# 236508   637.029053       4         15   Y  1909.07250 -9.965784
# 236509  2046.131500       4         16   Y  2046.13150 -9.965784

# %%
chunks = []
chunksize = 10 ** 6
with pd.read_table("data/PXD021398/msms_full.txt", chunksize=chunksize) as reader:
    for parts in reader:
        chunks.append(parts)
msms = pd.concat(chunks)
# Out:
# /home/arthur/miniconda3/envs/ms2pip-dev/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3364: DtypeWarning: Columns (8,9,56) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# /home/arthur/miniconda3/envs/ms2pip-dev/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3364: DtypeWarning: Columns (56) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# /home/arthur/miniconda3/envs/ms2pip-dev/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3364: DtypeWarning: Columns (8,9,11,56) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
msms.head()
# Out:
#                                             Raw file  Scan number  Scan index  \
# 0  C20150414_JGA_HLA_B57_star_3uLof6uL_5e7ceqonco...        19535       10232
# 1  M20150824_JGA_HLA_B4402_biorep1_5e7ceq_AcOHmob...        18925       17464
# 2  M20150626_JGA_HLA_B57_biorep2_5e7ceq_reinject_...        21933       17901
# 3  C20150414_JGA_HLA_B57_3uLof6uL_5e7ceqoncolumn_...        22498       11854
# 4  C20150414_JGA_HLA_B57_3uLof6uL_5e7ceqoncolumn_...        22595       11943
#
#                 Sequence  Length  Missed cleavages Modifications  \
# 0  AAAAAAAAAAAAAAAAAAYYQ      21               NaN    Unmodified
# 1       AAAAAAAAAAGGLAAA      16               NaN    Unmodified
# 2             AAAAAAAAAW      10               NaN    Unmodified
# 3             AAAAAAAAAW      10               NaN    Unmodified
# 4             AAAAAAAAAW      10               NaN    Unmodified
#
#          Modified sequence Oxidation (M) Probabilities  \
# 0  _AAAAAAAAAAAAAAAAAAYYQ_                         NaN
# 1       _AAAAAAAAAAGGLAAA_                         NaN
# 2             _AAAAAAAAAW_                         NaN
# 3             _AAAAAAAAAW_                         NaN
# 4             _AAAAAAAAAW_                         NaN
#
#   Oxidation (M) Score Diffs  ...  Reverse                  All scores  \
# 0                       NaN  ...      NaN  8.284077;7.582434;5.541086
# 1                       NaN  ...      NaN  2.221972;2.154223;2.154223
# 2                       NaN  ...      NaN   42.59861;37.55836;24.0301
# 3                       NaN  ...      NaN   24.7756;20.52031;17.23078
# 4                       NaN  ...      NaN   33.26252;29.37615;19.7865
#
#                                        All sequences  \
# 0  AAAAAAAAAAAAAAAAAAYYQ;AAAAAAAAAANGPAPTAAANAS;C...
# 1               AAAAAAAAAAGGLAAA;NVEKYRVVY;QHRQFQARV
# 2                      AAAAAAAAAW;VNNVAAAW;GVQAAAAWA
# 3                      AAAAAAAAAW;VNNVAAAW;GVQAAAAWA
# 4                      AAAAAAAAAW;VNNVAAAW;AAAAAAVHY
#
#                               All modified sequences id Protein group IDs  \
# 0  _AAAAAAAAAAAAAAAAAAYYQ_;_AAAAAAAAAANGPAPTAAANA...  0             71278
# 1         _AAAAAAAAAAGGLAAA_;_NVEKYRVVY_;_QHRQFQARV_  1             65369
# 2                _AAAAAAAAAW_;_VNNVAAAW_;_GVQAAAAWA_  2             70356
# 3                _AAAAAAAAAW_;_VNNVAAAW_;_GVQAAAAWA_  3             70356
# 4                _AAAAAAAAAW_;_VNNVAAAW_;_AAAAAAVHY_  4             70356
#
#    Peptide ID  Mod. peptide ID  Evidence ID  Oxidation (M) site IDs
# 0           0                0            0                     NaN
# 1           1                1            1                     NaN
# 2           2                2            2                     NaN
# 3           2                2            3                     NaN
# 4           2                2            3                     NaN
#
# [5 rows x 57 columns]

# %%
xl_file = pd.ExcelFile("/home/compomics/conode55_pride/Arthur/immunopeptidomics_PRIDE/PXD021398/NIHMS1541512-supplement-Sup_Data1.xlsx")

# %%
hla_alleles = xl_file.sheet_names[1:]

# %%
hla_raw_dict = {}
for hla_type in hla_alleles:
    hla_df = xl_file.parse(hla_type)
    hla_raw_dict[hla_type] = set(hla_df["filename"].str.split(".", 1, expand=True)[0])

# %%
raw_hla_map = {}
for hla, raw_file_list in hla_raw_dict.items():
    for rawfile in raw_file_list:
        raw_hla_map[rawfile] = hla

# %%
with open("data/PXD021398/HLA_allele_rawfile_mapping.pkl", "wb") as fp:
    pickle.dump(raw_hla_map, fp)
