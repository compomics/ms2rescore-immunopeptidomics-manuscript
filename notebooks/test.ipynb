# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from math import sqrt
from math import acos
from scipy.stats import pearsonr
import matplotlib.pyplot as plt
import seaborn as sns
from immuno_ms2rescore_tools.file_utilities import PrositLib
import pickle

# %%
def replace_modified_seq(prositlib_mods):
    """Replace prosit modifications to original maxquant modfications"""

    prositlib_mods = prositlib_mods.str.replace("[Carbamidomethyl (C)]", "(ca)", regex=False)
    prositlib_mods = prositlib_mods.str.replace("[Oxidation (O)]", "(ox)", regex=False)
    prositlib_mods = prositlib_mods.str.extract(r"_([A-Za-z\(\)]*)_")
    return prositlib_mods

# %%
df = pd.read_csv("/home/arthur/ms2rescore-immunopeptidomics-manuscript/notebooks/data/evaluation_data/PXD005231/PXD005231_prosit.csv")
prosit_lib = pd.read_csv("/home/arthur/ms2rescore-immunopeptidomics-manuscript/notebooks/data/evaluation_data/PXD005231/myPrositLib_PXD005231.csv")

# %%
prosit_lib.groupby("FragmentCharge").agg({"RelativeIntensity": "mean"})
# Out:
#                 RelativeIntensity
# FragmentCharge
# 1                        0.259549
# 2                        0.162173
# 3                        0.070651

# %%
prosit_lib[prosit_lib["ModifiedPeptide"].str.contains("[Oxidation (O)]", regex=False)]
# Out:
#         RelativeIntensity   FragmentMz             ModifiedPeptide  \
# 577              0.012161   166.053238  _AAAAVGPAM[Oxidation (O)]_
# 578              0.035727   237.090347  _AAAAVGPAM[Oxidation (O)]_
# 579              0.530723   334.143127  _AAAAVGPAM[Oxidation (O)]_
# 580              0.029304   214.118622  _AAAAVGPAM[Oxidation (O)]_
# 581              1.000000   391.164581  _AAAAVGPAM[Oxidation (O)]_
# ...                   ...          ...                         ...
# 836054           0.078581   873.381104  _YYDGKVM[Oxidation (O)]KL_
# 836055           0.263756   969.507385  _YYDGKVM[Oxidation (O)]KL_
# 836056           0.312582   485.257324  _YYDGKVM[Oxidation (O)]KL_
# 836057           0.020425  1001.476074  _YYDGKVM[Oxidation (O)]KL_
# 836058           0.118493   501.241669  _YYDGKVM[Oxidation (O)]KL_
#
#        LabeledPeptide StrippedPeptide  PrecursorCharge  PrecursorMz  \
# 577         AAAAVGPAM       AAAAVGPAM              1.0   774.374176
# 578         AAAAVGPAM       AAAAVGPAM              1.0   774.374176
# 579         AAAAVGPAM       AAAAVGPAM              1.0   774.374176
# 580         AAAAVGPAM       AAAAVGPAM              1.0   774.374176
# 581         AAAAVGPAM       AAAAVGPAM              1.0   774.374176
# ...               ...             ...              ...          ...
# 836054      YYDGKVMKL       YYDGKVMKL              2.0   566.781717
# 836055      YYDGKVMKL       YYDGKVMKL              2.0   566.781717
# 836056      YYDGKVMKL       YYDGKVMKL              2.0   566.781717
# 836057      YYDGKVMKL       YYDGKVMKL              2.0   566.781717
# 836058      YYDGKVMKL       YYDGKVMKL              2.0   566.781717
#
#               iRT  proteotypicity  FragmentNumber FragmentType  \
# 577     -1.834412        2.471413               1            y
# 578     -1.834412        2.471413               2            y
# 579     -1.834412        2.471413               3            y
# 580     -1.834412        2.471413               3            b
# 581     -1.834412        2.471413               4            y
# ...           ...             ...             ...          ...
# 836054  18.562275       -5.093276               7            b
# 836055  18.562275       -5.093276               8            y
# 836056  18.562275       -5.093276               8            y
# 836057  18.562275       -5.093276               8            b
# 836058  18.562275       -5.093276               8            b
#
#         FragmentCharge FragmentLossType
# 577                  1           noloss
# 578                  1           noloss
# 579                  1           noloss
# 580                  1           noloss
# 581                  1           noloss
# ...                ...              ...
# 836054               1           noloss
# 836055               1           noloss
# 836056               2           noloss
# 836057               1           noloss
# 836058               2           noloss
#
# [36859 rows x 13 columns]

# %%
prosit_lib = prosit_lib[~(prosit_lib["ModifiedPeptide"].str.contains("[Carbamidomethyl (C)]", regex=False))]
prosit_lib["ModifiedPeptide"] = replace_modified_seq(prosit_lib["ModifiedPeptide"])

# %%
prosit_lib[prosit_lib["ModifiedPeptide"].str.contains("(ox)", regex=False)]
# Out:
#         RelativeIntensity   FragmentMz ModifiedPeptide LabeledPeptide  \
# 577              0.012161   166.053238   AAAAVGPAM(ox)      AAAAVGPAM
# 578              0.035727   237.090347   AAAAVGPAM(ox)      AAAAVGPAM
# 579              0.530723   334.143127   AAAAVGPAM(ox)      AAAAVGPAM
# 580              0.029304   214.118622   AAAAVGPAM(ox)      AAAAVGPAM
# 581              1.000000   391.164581   AAAAVGPAM(ox)      AAAAVGPAM
# ...                   ...          ...             ...            ...
# 836054           0.078581   873.381104   YYDGKVM(ox)KL      YYDGKVMKL
# 836055           0.263756   969.507385   YYDGKVM(ox)KL      YYDGKVMKL
# 836056           0.312582   485.257324   YYDGKVM(ox)KL      YYDGKVMKL
# 836057           0.020425  1001.476074   YYDGKVM(ox)KL      YYDGKVMKL
# 836058           0.118493   501.241669   YYDGKVM(ox)KL      YYDGKVMKL
#
#        StrippedPeptide  PrecursorCharge  PrecursorMz        iRT  \
# 577          AAAAVGPAM              1.0   774.374176  -1.834412
# 578          AAAAVGPAM              1.0   774.374176  -1.834412
# 579          AAAAVGPAM              1.0   774.374176  -1.834412
# 580          AAAAVGPAM              1.0   774.374176  -1.834412
# 581          AAAAVGPAM              1.0   774.374176  -1.834412
# ...                ...              ...          ...        ...
# 836054       YYDGKVMKL              2.0   566.781717  18.562275
# 836055       YYDGKVMKL              2.0   566.781717  18.562275
# 836056       YYDGKVMKL              2.0   566.781717  18.562275
# 836057       YYDGKVMKL              2.0   566.781717  18.562275
# 836058       YYDGKVMKL              2.0   566.781717  18.562275
#
#         proteotypicity  FragmentNumber FragmentType  FragmentCharge  \
# 577           2.471413               1            y               1
# 578           2.471413               2            y               1
# 579           2.471413               3            y               1
# 580           2.471413               3            b               1
# 581           2.471413               4            y               1
# ...                ...             ...          ...             ...
# 836054       -5.093276               7            b               1
# 836055       -5.093276               8            y               1
# 836056       -5.093276               8            y               2
# 836057       -5.093276               8            b               1
# 836058       -5.093276               8            b               2
#
#        FragmentLossType
# 577              noloss
# 578              noloss
# 579              noloss
# 580              noloss
# 581              noloss
# ...                 ...
# 836054           noloss
# 836055           noloss
# 836056           noloss
# 836057           noloss
# 836058           noloss
#
# [36209 rows x 13 columns]

# %%
test_df = pd.merge(prosit_lib, df, left_on=["ModifiedPeptide", "PrecursorCharge"], right_on=["modified_sequence", "precursor_charge"], validate="many_to_one")

# %%
test_df["spec_id"][test_df["ModifiedPeptide"] == "AAAAAAAAR"].unique()
# Out:
# array(['mzspec:PXD005231:20160823_QEh1_LC2_HuPa_SA_HLApI_RA957_1_MG_1:scan:7536',
#        'mzspec:PXD005231:20160823_QEh1_LC2_HuPa_SA_HLApI_RA957_2_MG_1:scan:6482'],
#       dtype=object)

# %%
test_lib = PrositLib("/home/arthur/ms2rescore-immunopeptidomics-manuscript/notebooks/data/evaluation_data/PXD005231/myPrositLib_PXD005231.csv")

# %%
test_lib.merge_spec_ids("/home/arthur/ms2rescore-immunopeptidomics-manuscript/notebooks/data/evaluation_data/PXD005231/PXD005231_prosit.csv")

# %%
pred_emp = test_lib.create_pred_and_emp_csv("/home/arthur/ms2rescore-immunopeptidomics-manuscript/notebooks/data/evaluation_data/PXD005231/spec_lib_PXD005231_HCD_pred_and_emp.csv")
# Out:
# <class 'numpy.int64'> <class 'numpy.float64'>
# <class 'numpy.int64'> <class 'numpy.int64'>

# %%
pred_emp[pred_emp["spec_id"] == 'mzspec:PXD005231:20160823_QEh1_LC2_HuPa_SA_HLApI_RA957_2_MG_1:scan:6482']
# Out:
#                                                   spec_id  prediction  \
# 763840  mzspec:PXD005231:20160823_QEh1_LC2_HuPa_SA_HLA...   -9.965784
# 763841  mzspec:PXD005231:20160823_QEh1_LC2_HuPa_SA_HLA...   -9.965784
# 763842  mzspec:PXD005231:20160823_QEh1_LC2_HuPa_SA_HLA...   -4.042310
# 763843  mzspec:PXD005231:20160823_QEh1_LC2_HuPa_SA_HLA...   -2.262998
# 763844  mzspec:PXD005231:20160823_QEh1_LC2_HuPa_SA_HLA...   -0.986638
# 763845  mzspec:PXD005231:20160823_QEh1_LC2_HuPa_SA_HLA...   -0.172082
# 763846  mzspec:PXD005231:20160823_QEh1_LC2_HuPa_SA_HLA...   -0.214228
# 763847  mzspec:PXD005231:20160823_QEh1_LC2_HuPa_SA_HLA...   -1.923464
# 763848  mzspec:PXD005231:20160823_QEh1_LC2_HuPa_SA_HLA...    0.001442
# 763849  mzspec:PXD005231:20160823_QEh1_LC2_HuPa_SA_HLA...   -3.897951
# 763850  mzspec:PXD005231:20160823_QEh1_LC2_HuPa_SA_HLA...   -4.345068
# 763851  mzspec:PXD005231:20160823_QEh1_LC2_HuPa_SA_HLA...   -5.599401
# 763852  mzspec:PXD005231:20160823_QEh1_LC2_HuPa_SA_HLA...   -9.965784
# 763853  mzspec:PXD005231:20160823_QEh1_LC2_HuPa_SA_HLA...   -9.965784
# 763854  mzspec:PXD005231:20160823_QEh1_LC2_HuPa_SA_HLA...   -7.160347
# 763855  mzspec:PXD005231:20160823_QEh1_LC2_HuPa_SA_HLA...   -9.965784
#
#         FragmentMz  charge  ionnumber ion  FragmentCharge         mz    target
# 763840    0.000000       1          1   B             NaN   72.04435 -9.965784
# 763841    0.000000       1          2   B             NaN  143.08147 -8.534998
# 763842  214.118622       1          3   B             1.0  214.11859 -6.241658
# 763843  285.155731       1          4   B             1.0  285.15570 -5.275553
# 763844  356.192841       1          5   B             1.0  356.19280 -4.712230
# 763845  427.229950       1          6   B             1.0  427.22992 -4.483859
# 763846  498.267059       1          7   B             1.0  498.26703 -5.528564
# 763847  569.304199       1          8   B             1.0  569.30420 -6.988497
# 763848  175.118958       1          1   Y             1.0  175.11891 -4.591251
# 763849  246.156067       1          2   Y             1.0  246.15602 -8.105649
# 763850  317.193176       1          3   Y             1.0  317.19310 -8.016012
# 763851  388.230286       1          4   Y             1.0  388.23022 -8.201345
# 763852    0.000000       1          5   Y             NaN  459.26733 -8.516015
# 763853    0.000000       1          6   Y             NaN  530.30444 -9.965784
# 763854  601.341614       1          7   Y             1.0  601.34160 -8.631353
# 763855    0.000000       1          8   Y             NaN  672.37870 -9.965784

# %%
pxd008034 = pd.read_csv("data/evaluation_data/PXD008034/PXD008034_prosit.csv")
